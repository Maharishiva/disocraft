# %% [markdown]
# # Disocraft Colab Training
#
# This notebook clones the repo, initializes submodules, installs deps,
# applies the DiscoRL patch, and runs training.

# %%
# !git clone https://github.com/Maharishiva/disocraft.git
# %cd disocraft
# !git submodule update --init --recursive
# Out:
# Cloning into 'disocraft'...
# remote: Enumerating objects: 44, done.
# remote: Counting objects: 100% (44/44), done.
# remote: Compressing objects: 100% (33/33), done.
# remote: Total 44 (delta 17), reused 35 (delta 8), pack-reused 0 (from 0)
# Receiving objects: 100% (44/44), 17.91 KiB | 17.91 MiB/s, done.
# Resolving deltas: 100% (17/17), done.
# /content/disocraft/disocraft
# Submodule 'external/Craftax' (https://github.com/MichaelTMatthews/Craftax.git) registered for path 'external/Craftax'
# Submodule 'external/disco_rl' (https://github.com/google-deepmind/disco_rl.git) registered for path 'external/disco_rl'
# Cloning into '/content/disocraft/disocraft/external/Craftax'...
# Cloning into '/content/disocraft/disocraft/external/disco_rl'...
# Submodule path 'external/Craftax': checked out 'bcc0fae62060579de4dee63dbb4e8dc729588173'
# Submodule path 'external/disco_rl': checked out '9059a29f7121d60948f25ef165e08e050e9399c8'

# %%
# Install JAX with CUDA (A100).
# !pip install -U "jax[cuda12]" -f https://storage.googleapis.com/jax-releases/jax_cuda_releases.html
# Out:
# Looking in links: https://storage.googleapis.com/jax-releases/jax_cuda_releases.html
# Requirement already satisfied: jax[cuda12] in /usr/local/lib/python3.12/dist-packages (0.8.2)
# Requirement already satisfied: jaxlib<=0.8.2,>=0.8.2 in /usr/local/lib/python3.12/dist-packages (from jax[cuda12]) (0.8.2)
# Requirement already satisfied: ml_dtypes>=0.5.0 in /usr/local/lib/python3.12/dist-packages (from jax[cuda12]) (0.5.4)
# Requirement already satisfied: numpy>=2.0 in /usr/local/lib/python3.12/dist-packages (from jax[cuda12]) (2.0.2)
# Requirement already satisfied: opt_einsum in /usr/local/lib/python3.12/dist-packages (from jax[cuda12]) (3.4.0)
# Requirement already satisfied: scipy>=1.13 in /usr/local/lib/python3.12/dist-packages (from jax[cuda12]) (1.16.3)
# Requirement already satisfied: jax-cuda12-plugin<=0.8.2,>=0.8.2 in /usr/local/lib/python3.12/dist-packages (from jax-cuda12-plugin[with-cuda]<=0.8.2,>=0.8.2; extra == "cuda12"->jax[cuda12]) (0.8.2)
# Requirement already satisfied: jax-cuda12-pjrt==0.8.2 in /usr/local/lib/python3.12/dist-packages (from jax-cuda12-plugin<=0.8.2,>=0.8.2->jax-cuda12-plugin[with-cuda]<=0.8.2,>=0.8.2; extra == "cuda12"->jax[cuda12]) (0.8.2)
# Requirement already satisfied: nvidia-cublas-cu12>=12.1.3.1 in /usr/local/lib/python3.12/dist-packages (from jax-cuda12-plugin[with-cuda]<=0.8.2,>=0.8.2; extra == "cuda12"->jax[cuda12]) (12.6.4.1)
# Requirement already satisfied: nvidia-cuda-cupti-cu12>=12.1.105 in /usr/local/lib/python3.12/dist-packages (from jax-cuda12-plugin[with-cuda]<=0.8.2,>=0.8.2; extra == "cuda12"->jax[cuda12]) (12.6.80)
# Requirement already satisfied: nvidia-cuda-nvcc-cu12>=12.6.85 in /usr/local/lib/python3.12/dist-packages (from jax-cuda12-plugin[with-cuda]<=0.8.2,>=0.8.2; extra == "cuda12"->jax[cuda12]) (12.9.86)
# Requirement already satisfied: nvidia-cuda-runtime-cu12>=12.1.105 in /usr/local/lib/python3.12/dist-packages (from jax-cuda12-plugin[with-cuda]<=0.8.2,>=0.8.2; extra == "cuda12"->jax[cuda12]) (12.6.77)
# Requirement already satisfied: nvidia-cudnn-cu12<10.0,>=9.8 in /usr/local/lib/python3.12/dist-packages (from jax-cuda12-plugin[with-cuda]<=0.8.2,>=0.8.2; extra == "cuda12"->jax[cuda12]) (9.10.2.21)
# Requirement already satisfied: nvidia-cufft-cu12>=11.0.2.54 in /usr/local/lib/python3.12/dist-packages (from jax-cuda12-plugin[with-cuda]<=0.8.2,>=0.8.2; extra == "cuda12"->jax[cuda12]) (11.3.0.4)
# Requirement already satisfied: nvidia-cusolver-cu12>=11.4.5.107 in /usr/local/lib/python3.12/dist-packages (from jax-cuda12-plugin[with-cuda]<=0.8.2,>=0.8.2; extra == "cuda12"->jax[cuda12]) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12>=12.1.0.106 in /usr/local/lib/python3.12/dist-packages (from jax-cuda12-plugin[with-cuda]<=0.8.2,>=0.8.2; extra == "cuda12"->jax[cuda12]) (12.5.4.2)
# Requirement already satisfied: nvidia-nccl-cu12>=2.18.1 in /usr/local/lib/python3.12/dist-packages (from jax-cuda12-plugin[with-cuda]<=0.8.2,>=0.8.2; extra == "cuda12"->jax[cuda12]) (2.27.5)
# Requirement already satisfied: nvidia-nvjitlink-cu12>=12.1.105 in /usr/local/lib/python3.12/dist-packages (from jax-cuda12-plugin[with-cuda]<=0.8.2,>=0.8.2; extra == "cuda12"->jax[cuda12]) (12.6.85)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12>=12.1.55 in /usr/local/lib/python3.12/dist-packages (from jax-cuda12-plugin[with-cuda]<=0.8.2,>=0.8.2; extra == "cuda12"->jax[cuda12]) (12.6.77)
# Requirement already satisfied: nvidia-nvshmem-cu12>=3.2.5 in /usr/local/lib/python3.12/dist-packages (from jax-cuda12-plugin[with-cuda]<=0.8.2,>=0.8.2; extra == "cuda12"->jax[cuda12]) (3.3.20)

# %%
# !pip install -r requirements.txt
# Out:
# Obtaining file:///content/disocraft/disocraft/external/disco_rl (from -r requirements.txt (line 1))
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# Obtaining file:///content/disocraft/disocraft/external/Craftax (from -r requirements.txt (line 2))
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# Requirement already satisfied: chex in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 3)) (0.1.90)
# Requirement already satisfied: dm-env in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 4)) (1.6)
# Requirement already satisfied: jax in /usr/local/lib/python3.12/dist-packages (from disco_rl==1.0.0->-r requirements.txt (line 1)) (0.8.2)
# Requirement already satisfied: distrax in /usr/local/lib/python3.12/dist-packages (from disco_rl==1.0.0->-r requirements.txt (line 1)) (0.1.7)
# Requirement already satisfied: optax in /usr/local/lib/python3.12/dist-packages (from disco_rl==1.0.0->-r requirements.txt (line 1)) (0.2.6)
# Requirement already satisfied: jmp in /usr/local/lib/python3.12/dist-packages (from disco_rl==1.0.0->-r requirements.txt (line 1)) (0.0.4)
# Requirement already satisfied: rlax in /usr/local/lib/python3.12/dist-packages (from disco_rl==1.0.0->-r requirements.txt (line 1)) (0.1.8)
# Requirement already satisfied: dm-haiku in /usr/local/lib/python3.12/dist-packages (from disco_rl==1.0.0->-r requirements.txt (line 1)) (0.0.16)
# Requirement already satisfied: immutabledict in /usr/local/lib/python3.12/dist-packages (from disco_rl==1.0.0->-r requirements.txt (line 1)) (4.2.2)
# Requirement already satisfied: ml_collections in /usr/local/lib/python3.12/dist-packages (from disco_rl==1.0.0->-r requirements.txt (line 1)) (1.1.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from disco_rl==1.0.0->-r requirements.txt (line 1)) (3.10.0)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.12/dist-packages (from disco_rl==1.0.0->-r requirements.txt (line 1)) (0.13.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from disco_rl==1.0.0->-r requirements.txt (line 1)) (2.2.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from disco_rl==1.0.0->-r requirements.txt (line 1)) (4.67.1)
# Requirement already satisfied: flax in /usr/local/lib/python3.12/dist-packages (from craftax==1.5.0->-r requirements.txt (line 2)) (0.10.7)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from craftax==1.5.0->-r requirements.txt (line 2)) (2.0.2)
# Requirement already satisfied: pygame in /usr/local/lib/python3.12/dist-packages (from craftax==1.5.0->-r requirements.txt (line 2)) (2.6.1)
# Requirement already satisfied: gymnax in /usr/local/lib/python3.12/dist-packages (from craftax==1.5.0->-r requirements.txt (line 2)) (0.0.9)
# Requirement already satisfied: imageio in /usr/local/lib/python3.12/dist-packages (from craftax==1.5.0->-r requirements.txt (line 2)) (2.37.2)
# Requirement already satisfied: absl-py>=0.9.0 in /usr/local/lib/python3.12/dist-packages (from chex->-r requirements.txt (line 3)) (2.3.1)
# Requirement already satisfied: typing_extensions>=4.2.0 in /usr/local/lib/python3.12/dist-packages (from chex->-r requirements.txt (line 3)) (4.15.0)
# Requirement already satisfied: jaxlib>=0.4.27 in /usr/local/lib/python3.12/dist-packages (from chex->-r requirements.txt (line 3)) (0.8.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from chex->-r requirements.txt (line 3)) (75.2.0)
# Requirement already satisfied: toolz>=0.9.0 in /usr/local/lib/python3.12/dist-packages (from chex->-r requirements.txt (line 3)) (0.12.1)
# Requirement already satisfied: dm-tree in /usr/local/lib/python3.12/dist-packages (from dm-env->-r requirements.txt (line 4)) (0.1.9)
# Requirement already satisfied: ml_dtypes>=0.5.0 in /usr/local/lib/python3.12/dist-packages (from jax->disco_rl==1.0.0->-r requirements.txt (line 1)) (0.5.4)
# Requirement already satisfied: opt_einsum in /usr/local/lib/python3.12/dist-packages (from jax->disco_rl==1.0.0->-r requirements.txt (line 1)) (3.4.0)
# Requirement already satisfied: scipy>=1.13 in /usr/local/lib/python3.12/dist-packages (from jax->disco_rl==1.0.0->-r requirements.txt (line 1)) (1.16.3)
# Requirement already satisfied: tfp-nightly in /usr/local/lib/python3.12/dist-packages (from distrax->disco_rl==1.0.0->-r requirements.txt (line 1)) (0.26.0.dev20260110)
# Requirement already satisfied: tabulate>=0.8.9 in /usr/local/lib/python3.12/dist-packages (from dm-haiku->disco_rl==1.0.0->-r requirements.txt (line 1)) (0.9.0)
# Requirement already satisfied: attrs>=18.2.0 in /usr/local/lib/python3.12/dist-packages (from dm-tree->dm-env->-r requirements.txt (line 4)) (25.4.0)
# Requirement already satisfied: wrapt>=1.11.2 in /usr/local/lib/python3.12/dist-packages (from dm-tree->dm-env->-r requirements.txt (line 4)) (2.0.1)
# Requirement already satisfied: msgpack in /usr/local/lib/python3.12/dist-packages (from flax->craftax==1.5.0->-r requirements.txt (line 2)) (1.1.2)
# Requirement already satisfied: orbax-checkpoint in /usr/local/lib/python3.12/dist-packages (from flax->craftax==1.5.0->-r requirements.txt (line 2)) (0.11.31)
# Requirement already satisfied: tensorstore in /usr/local/lib/python3.12/dist-packages (from flax->craftax==1.5.0->-r requirements.txt (line 2)) (0.1.80)
# Requirement already satisfied: rich>=11.1 in /usr/local/lib/python3.12/dist-packages (from flax->craftax==1.5.0->-r requirements.txt (line 2)) (13.9.4)
# Requirement already satisfied: PyYAML>=5.4.1 in /usr/local/lib/python3.12/dist-packages (from flax->craftax==1.5.0->-r requirements.txt (line 2)) (6.0.3)
# Requirement already satisfied: treescope>=0.1.7 in /usr/local/lib/python3.12/dist-packages (from flax->craftax==1.5.0->-r requirements.txt (line 2)) (0.1.10)
# Requirement already satisfied: gymnasium in /usr/local/lib/python3.12/dist-packages (from gymnax->craftax==1.5.0->-r requirements.txt (line 2)) (1.2.2)
# Requirement already satisfied: pillow>=8.3.2 in /usr/local/lib/python3.12/dist-packages (from imageio->craftax==1.5.0->-r requirements.txt (line 2)) (11.3.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->disco_rl==1.0.0->-r requirements.txt (line 1)) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->disco_rl==1.0.0->-r requirements.txt (line 1)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->disco_rl==1.0.0->-r requirements.txt (line 1)) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->disco_rl==1.0.0->-r requirements.txt (line 1)) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->disco_rl==1.0.0->-r requirements.txt (line 1)) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->disco_rl==1.0.0->-r requirements.txt (line 1)) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->disco_rl==1.0.0->-r requirements.txt (line 1)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->disco_rl==1.0.0->-r requirements.txt (line 1)) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->disco_rl==1.0.0->-r requirements.txt (line 1)) (2025.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->disco_rl==1.0.0->-r requirements.txt (line 1)) (1.17.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=11.1->flax->craftax==1.5.0->-r requirements.txt (line 2)) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=11.1->flax->craftax==1.5.0->-r requirements.txt (line 2)) (2.19.2)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium->gymnax->craftax==1.5.0->-r requirements.txt (line 2)) (3.1.2)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.12/dist-packages (from gymnasium->gymnax->craftax==1.5.0->-r requirements.txt (line 2)) (0.0.4)
# Requirement already satisfied: etils[epath,epy] in /usr/local/lib/python3.12/dist-packages (from orbax-checkpoint->flax->craftax==1.5.0->-r requirements.txt (line 2)) (1.13.0)
# Requirement already satisfied: nest_asyncio in /usr/local/lib/python3.12/dist-packages (from orbax-checkpoint->flax->craftax==1.5.0->-r requirements.txt (line 2)) (1.6.0)
# Requirement already satisfied: aiofiles in /usr/local/lib/python3.12/dist-packages (from orbax-checkpoint->flax->craftax==1.5.0->-r requirements.txt (line 2)) (24.1.0)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.12/dist-packages (from orbax-checkpoint->flax->craftax==1.5.0->-r requirements.txt (line 2)) (5.29.5)
# Requirement already satisfied: humanize in /usr/local/lib/python3.12/dist-packages (from orbax-checkpoint->flax->craftax==1.5.0->-r requirements.txt (line 2)) (4.14.0)
# Requirement already satisfied: simplejson>=3.16.0 in /usr/local/lib/python3.12/dist-packages (from orbax-checkpoint->flax->craftax==1.5.0->-r requirements.txt (line 2)) (3.20.2)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from orbax-checkpoint->flax->craftax==1.5.0->-r requirements.txt (line 2)) (5.9.5)
# Requirement already satisfied: decorator in /usr/local/lib/python3.12/dist-packages (from tfp-nightly->distrax->disco_rl==1.0.0->-r requirements.txt (line 1)) (4.4.2)
# Requirement already satisfied: gast>=0.3.2 in /usr/local/lib/python3.12/dist-packages (from tfp-nightly->distrax->disco_rl==1.0.0->-r requirements.txt (line 1)) (0.7.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=11.1->flax->craftax==1.5.0->-r requirements.txt (line 2)) (0.1.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from etils[epath,epy]->orbax-checkpoint->flax->craftax==1.5.0->-r requirements.txt (line 2)) (2025.3.0)
# Requirement already satisfied: importlib_resources in /usr/local/lib/python3.12/dist-packages (from etils[epath,epy]->orbax-checkpoint->flax->craftax==1.5.0->-r requirements.txt (line 2)) (6.5.2)
# Requirement already satisfied: zipp in /usr/local/lib/python3.12/dist-packages (from etils[epath,epy]->orbax-checkpoint->flax->craftax==1.5.0->-r requirements.txt (line 2)) (3.23.0)
# Building wheels for collected packages: disco_rl, craftax
#   Building editable for disco_rl (pyproject.toml) ... done
#   Created wheel for disco_rl: filename=disco_rl-1.0.0-0.editable-py3-none-any.whl size=8825 sha256=e04c06cd7ad8eb40627a9216f78fdce3152db85cb11b10d41ddb0655ded8b1d2
#   Stored in directory: /tmp/pip-ephem-wheel-cache-1rquboxi/wheels/46/12/44/1a1b6f4b07feb04b567081951339b666601510ec173feaa9b4
#   Building editable for craftax (pyproject.toml) ... done
#   Created wheel for craftax: filename=craftax-1.5.0-0.editable-py3-none-any.whl size=7752 sha256=f55ebcb1427d263831fcdac7275417471e53b6b4e578568587c32829faf136c4
#   Stored in directory: /tmp/pip-ephem-wheel-cache-1rquboxi/wheels/57/d9/e1/5fbd46f019125df41abeef546f4572721b06a7058d79b6f27d
# Successfully built disco_rl craftax
# Installing collected packages: disco_rl, craftax
#   Attempting uninstall: disco_rl
#     Found existing installation: disco_rl 1.0.0
#     Uninstalling disco_rl-1.0.0:
#       Successfully uninstalled disco_rl-1.0.0
#   Attempting uninstall: craftax
#     Found existing installation: craftax 1.5.0
#     Uninstalling craftax-1.5.0:
#       Successfully uninstalled craftax-1.5.0
# Successfully installed craftax-1.5.0 disco_rl-1.0.0

# %%
# !python scripts/patch_disco_rl.py
# Out:
# Patched /content/disocraft/disocraft/external/disco_rl/disco_rl/networks/meta_nets.py

# %%
# !mkdir -p runs

# %%
# Short test run (smoke test).
# Uses >=4 envs and batch_size=4 to trigger a learner update on iter 1.
# !XLA_PYTHON_CLIENT_PREALLOCATE=false MPLCONFIGDIR=./.mplconfig python train.py \
  --num_iterations 5 \
  --num_envs 4 \
  --rollout_len 32 \
  --batch_size 4 \
  --buffer_capacity_transitions 10000 \
  --log_every 1
# Out:
# 2026-01-11 01:00:28.695595: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1768093228.716898   25804 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1768093228.723427   25804 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1768093228.740032   25804 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1768093228.740058   25804 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1768093228.740061   25804 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1768093228.740063   25804 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# Processing Craftax textures. This will take a minute but will be cached for future use.

# %%
# 1M env steps (~1e6).
# steps ~= num_iterations * rollout_len * num_envs
# !XLA_PYTHON_CLIENT_PREALLOCATE=false MPLCONFIGDIR=./.mplconfig python train.py \
  --num_iterations 1078 \
  --num_envs 32 \
  --rollout_len 29 \
  --batch_size 24 \
  --replay_fraction 0.99 \
  --buffer_capacity_transitions 400000 \
  --learning_rate 3e-4 \
  --log_every 10 |& tee runs/train_1m.log

# %%
# 20M env steps (~2e7).
# steps ~= num_iterations * rollout_len * num_envs
# !XLA_PYTHON_CLIENT_PREALLOCATE=false MPLCONFIGDIR=./.mplconfig python train.py \
  --num_iterations 21552 \
  --num_envs 32 \
  --rollout_len 29 \
  --batch_size 24 \
  --replay_fraction 0.99 \
  --buffer_capacity_transitions 400000 \
  --learning_rate 3e-4 \
  --log_every 10 |& tee runs/train_20m.log

# %%
# Plot returns.
import re
import matplotlib.pyplot as plt

xs, ys = [], []
log_path = 'runs/train_1m.log'
# Set log_path to runs/train_20m.log for the longer run.
with open(log_path) as f:
    for line in f:
        m = re.search(r'steps=(\d+).*avg_return=([0-9.]+)', line)
        if m:
            xs.append(int(m.group(1)))
            ys.append(float(m.group(2)))

plt.plot(xs, ys)
plt.xlabel('env steps')
plt.ylabel('avg_return')
plt.title('Craftax Disco103')
plt.grid(True, alpha=0.3)
plt.show()
